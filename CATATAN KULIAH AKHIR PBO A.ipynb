# %% [markdown]
# # CLASS VS OBJECT
# PENGENALAN CLASS DAN OBJECT

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# keyword class diikuti dengan nama class yang kita inginkan. Lebih baik digunakan kata yang diawali huruf kapital.Constructor menggunakan method bawaan Python yang bernama init(). Metode __init__() adalah metode konstruktor, yaitu metode khusus yang digunakan Python untuk menginisialisasi pembuatan objek dari kelas tersebut. Setiap method harus memiliki parameter self yang artinya method tersebut dimiliki dan terdaftar ke class tersebut untuk membedakan dari method atau fungsi yang ada di luar class.

# %% [markdown]
# # DEFINITION OF CLASS

# %% [markdown]
# A class is a code template for creating objects. Objects have member variables and have behaviour associated with them. In python a class is created by the keyword class.
#
# Struktur data yang bisa kita gunakan untuk mendefinisikan objek yang menyimpan data bersama-sama nilai-nilai dan perilaku (behavior). Kelas adalah suatu entitas yang merupakan bentuk program dari suatu abstraksi untuk permasalahan dunia nyata, dan instans dari class merupakan realisasi dari beberapa objek.

# %% [markdown]
# # DEFINITION OF OBJECT

# %% [markdown]
# An object is created using the constructor of the class.
# This object will then be called the instance of the class.
#
# Instance dari class. Jika class secara umum merepresentasikan(template) sebuah object, maka sebuah instance adalah representasi nyata dari class itu sendiri.

# %% [markdown]
# Berikut contoh-contoh program dari CLASS VS OBJECT:

# %%
class kubus:
    def __init__(self, sisi):
        self.sisi = sisi
    def tampilansisi(self):
        print(self.sisi)
    def luas(self):
        print("Luas : ",self.sisi**2)
    def luaspermukaan(self):
        print("Luas permukaan :",self.sisi**2*6)
    def volume(self):
        print("volume :",self.sisi**3)
        
kubus1 = kubus(8)
kubus1.tampilansisi()
kubus1.luas()
kubus1.luaspermukaan()
kubus1.volume()
# Out:
# 8
# Luas :  64
# Luas permukaan : 384
# volume : 512

# %%
from datetime import datetime
sekarang = datetime.now()
tahun = sekarang.year

class pegawai:
    def __init__(self,nm,jbt,gj,thnlhr):
        self.nama = nm
        self.jabatan = jbt
        self.gaji = gj
        self.tahunlahir = thnlhr
    def tampilan(self):
        print(self.nama,",",self.jabatan,",",self.gaji*15)
    def tampilanumur(self):
        print("Umur :",tahun - self.tahunlahir)
        
p1=pegawai("Mohammad Bisri Amin","Direktur",1200000,1999)
p1.tampilan()
p1.tampilanumur()
# Out:
# Mohammad Bisri Amin , Direktur , 18000000
# Umur : 20

# %%
class mahasiswa:
    def __init__(self,nm,nim,ip):
        self.nama = nm
        self.nim = nim
        self.ipk = ip
    def cek_kelayakan(self):
        if(self.ipk<2.75):
            print(self.nama,"Anda Tidak Layak untuk mendapatkan Beasiswa Bidikmisi")
        else:
            print(self.nama,"Anda Layak untuk mendapatkan Beasiswa Bidikmisi")
    def datamhs(self):
        print(self.nama,",",self.nim,",",self.ipk)
        
m1 = mahasiswa("Mohammad Bisri Amin","180441100024",2.30)
m1.datamhs()
m1.cek_kelayakan()
m2 = mahasiswa("Moh.Nu'man","180441100123",3.48)
m2.datamhs()
m2.cek_kelayakan()
# Out:
# Mohammad Bisri Amin , 180441100024 , 2.3
# Mohammad Bisri Amin Anda Tidak Layak untuk mendapatkan Beasiswa Bidikmisi
# Moh.Nu'man , 180441100123 , 3.48
# Moh.Nu'man Anda Layak untuk mendapatkan Beasiswa Bidikmisi

# %% [markdown]
# # INHERITANCE
# PENGENALAN MATERI PEWARISAN
#
# Type of Inhertance:

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# Contoh Pewarisan:

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# Definisi:
#
# 1. Kelas dapat mewakili fungsionalitas kelas lain. Jika suatu objek dibuat menggunakan kelas yang mewarisi dari superclass, objek tersebut akan berisi metode class dan superclass.
# 2. Warisan adalah sebuah proses dimana sebuah class mengambil semua properti dan semua metode dari classlain. jika, kita berfikir tentang pewarisan dalam hal biologi, kita dapat memikirkan seorang anak yang mewarisi sifat-sifat tertentu dari orang tua mereka. Artinya,seorang anak dapat mewarisi tinggi badan atau warna kulit orang tua. Anak-anak juga dapat berbagi nama belakang yang sama dengan orang tua mereka.
# 3. Class yang disebut class anak atau subclass mewarisi metode dan properti dari class induk atau class dasar.

# %% [markdown]
# Contoh-contoh program dalam Inheritance:

# %%
class user:
    nama = ""
    def __init__(self,namadepan):
        self.namadepan = namadepan
        print("Nama Depan saya",self.namadepan)
class programmer(user):
    def __init__(self,namadepan,namabelakang):
        super().__init__(namadepan)
        print("Nama Belakang saya",namabelakang)
        self.namabelakang = namabelakang
    def dophyton(self):
        print("Designer Database")
    def tampilkannama(self):
        print("Nama : ",self.namadepan,self.namabelakang)
        
brian = user("brian")
diana = programmer("Diana","Maya")
diana.tampilkannama()
diana.dophyton()
# Out:
# Nama Depan saya brian
# Nama Depan saya Diana
# Nama Belakang saya Maya
# Nama :  Diana Maya
# Designer Database

# %%
class fish:
    def __init__(self,first_name,last_name="fish",skleton="bone",eyelids=False):
        self.first_name = first_name
        self.last_name = last_name
        self.skleton = skleton
        self.eyelids = eyelids
    def swim(self):
        print("The fish is swimming")
    def swim_backwards(self):
        print("The fish can swim backwards")
        
class Trout(fish):
    pass
class clownfish(fish):
    def live_with_anemone(self):
        print("The clownfish is coexisting with sea anemone")
        
class shark(fish):
    def __init__(self,first_name,last_name="shark",skleton="cartilage",eyelids=True):
        self.first_name = first_name
        self.last_name = last_name
        self.skleton = skleton
        self.eyelids = eyelids
    def swim_backwards(self):
        print("The shark can't swim backwards,but can sink backwards")
        
class ikan(fish):
    def __init__(self,water,first_name,last_name,skleton,eyelids):
        self.water = water
        fish.__init__(self)
        #atau
        super().__init__(self)
        
terry = Trout("Terry")
print(terry.first_name+" "+terry.last_name)
print(terry.skleton)
print(terry.eyelids)
terry.swim()
terry.swim_backwards()

casey = clownfish("casey")
print(casey.first_name+" "+casey.last_name)
casey.swim()
casey.live_with_anemone
# Out:
# Terry fish
# bone
# False
# The fish is swimming
# The fish can swim backwards
# casey fish
# The fish is swimming
# <bound method clownfish.live_with_anemone of <__main__.clownfish object at 0x00000233BC2D8CF8>>

# %% [markdown]
# # REVIEW AND POLYMORPHISME

# %% [markdown]
# Ilustrasi:

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
#    Terkadang suatu objek datang dalam banyak jenis atau bentuk. Jika kita memiliki tombol, ada banyak output draw yang berbeda (tombol bulat, tombol periksa, tombol kotak, tombol dengan gambar) tetapi mereka berbagi logika yang sama: onClick (). Kami mengaksesnya menggunakan metode yang sama. Gagasan ini disebut Polimorphisme.

# %% [markdown]
# Polimorfisme didasarkan pada kata-kata Yunani Poli (banyak) dan morfisme (bentuk). Kami akan membuat struktur yang dapat mengambil atau menggunakan banyak bentuk objek.

# %%
class shark:
    def swim(self):
        print("The Shark is swimming")
    def swim_backwards(self):
        print("The shark can not swim backwards, but can sink backwards")
    def skleton(self):
        print("The shark's skleton is made of cartilage")
class clownfish():
    def swim(self):
        print("The clownfish is swimming")
    def swim_backwards(self):
        print("The clownfish can swim backwards")
    def skleton(self):
        print("The clownfish's skleton is made of bone")
        
sammy = shark()
sammy.skleton()
cassy = clownfish()
cassy.skleton()
# Out:
# The shark's skleton is made of cartilage
# The clownfish's skleton is made of bone

# %% [markdown]
# Polymorphisme with a Function

# %%
def di_pasifik(fish):
    fish.swim
    
di_pasifik(sammy)
di_pasifik(cassy)

# %%
class bear:
    def sound(self):
        print("gerrrrr")
class dog:
    def sound(self):
        print("hug hug hug")
        
def make_sound(animal):
        animal.sound()
        
beruang = bear()
anjing = dog()

make_sound(beruang)
make_sound(anjing)
# Out:
# gerrrrr
# hug hug hug

# %% [markdown]
# Polymophisme with class method

# %% [markdown]
# ![6.png](attachment:6.png)

# %%
class Document:
    def __init__(self, name):
        self.name = name
 
    def show(self):
        raise NotImplementedError("Subclass must implement abstract method")
 
class Pdf(Document):
    def show(self):
        return 'Show pdf contents!'
 
class Word(Document):
    def show(self):
        return 'Show word contents!'
 
Documents = [Pdf('Document1'),
            Pdf('Document2'),
            Word('Document3')]
 
for Document in Documents:
    print(Document.name + ': ' + Document.show())
# Out:
# Document1: Show pdf contents!
# Document2: Show pdf contents!
# Document3: Show word contents!

# %%
class car:
    def __init__(self, nama):
        self.nama = nama
    def drive(self):
        raise NotImplementedError("Subclass must implement abstract method")
    def stop(self):
        raise NotImplementedError("Subclass must implement abstract method")
class sportscar(car):
    def drive(self):
        return 'sportscar driving'
    def stop(self):
        return 'sportscar breaking'
class truck(car):
    def drive(self):
        return 'Truck driving slowly because heavily loaded'
    def stop(self):
        return 'Truck breaking'
cars = [truck('Bananatruck'),truck('Orangetruck'),sportscar('Z3')]
for car in cars:
    print(car.nama + ': ' + car.drive())
# Out:
# Bananatruck: Truck driving slowly because heavily loaded
# Orangetruck: Truck driving slowly because heavily loaded
# Z3: sportscar driving

# %% [markdown]
# # OPERATOR DAN METHOD OVERLOADING
#     In Phyton

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# Ada beberapa cara untuk memanggil atau menampilkan (metode overloading)
# 1. Dalam Phyton, user dapat mendefinisikan metode sedemikian rupa sehingga ada beberapa cara untuk menyebutnya.
# 2. Diberikan atau atau fungsi tunggal, kita dapat menemukan dan menentukan jumlah parameter tersendiri.
#
# Bergantng pada definisi fungsi, dapat dipanggil dengan parameter nol, satu, dua atau lebih. ini dikenal sebagai metode overloading. tidak semua  bahasa pemrograman mendukung metode overloading, tetapi phyton melakukannya.
#
# operator overloading berarti memberikan makna yang di perluas di luar makna operasional yang telah ditentukan sebelumnya. misalnya operator + digunakan untuk menambahkan dua bilangan bulat serta menggabungkan dua string dan menggabungkan dua daftar. ini dapat dicapai karena operator '+'  kelebihan beban oleh kelas integer dan string. di bawah adalah contoh program:

# %%
class Human:
    def sayHello(self, name=None):
        if name is not None:
            print("Hello" + name)
        else:print("Hello")
#create instance
obj = Human()

#call the method
obj.sayHello()

#call the method with a parameter
obj.sayHello("Guido")
# Out:
# Hello
# HelloGuido

# %% [markdown]
# _Magic Method_
#
# Operator overloading dicapai dengan mendifinisikan metode khusus dalam definisi kelas

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %% [markdown]
# ![3.JPG](attachment:3.JPG)

# %% [markdown]
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# ![5.JPG](attachment:5.JPG)

# %%
class Point:
    def __init__(self,a,b):
        self.a = a
        self.b = b
    #def __str__(self):
        #return "({0},{1})".format(self.a,self.b)
    def __str__(self):
        return "Poin object is at:("+str(self.a)+","+str(self.b)+")"
    def __sub__(self,other):
        a = self.a - other.a
        b = self.b - other.b
        return Point(a,b)
    def __add__(self,other):
        a = self.a + other.a
        b = self.b + other.b
        return Point(a,b)
    
p1 = Point(3,4)
p2 = Point(2,3)
print(p1-p2)
print(p1+p2)
# Out:
# Poin object is at:(1,1)
# Poin object is at:(5,7)

# %%
class fraction:
    def __init__(self,top,bottom):
        self.atas = top
        self.bawah = bottom
    #def show(self):
        #print(self.num, "/", self.den)
    def __str__(self):
        return str(self.atas)+"/"+str(self.bawah)
    
    def __add__(self,other):
        newatas = self.atas * other.bawah + self.bawah * other.atas
        newbawah = self.bawah * other.bawah
        return fraction(newatas,newbawah)
    def __sub__(self,other):
        newatas = self.atas * other.bawah - self.bawah * other.atas
        newbawah = self.bawah * other.bawah
        return fraction(newatas,newbawah)
    def __truediv__(self,other):
        newatas = self.atas * other.bawah
        newbawah = self.bawah * other.atas
        return fraction(newatas,newbawah)
    def __mul__(self,other):
        newatas = self.atas * other.atas
        newbawah = self.bawah  * other.bawah
        return fraction(newatas,newbawah)
        
f=fraction(2,4)
#show(f)
print(f)

f1 = fraction(2,5)
f2 = fraction(1,3)
print("hasil tambah pecahan :", f1+f2)
print("hasil kurang pecahan :", f1-f2)
print("hasil bagi pecahan :", f1/f2)
print("hasil kali pecahan :", f1*f2)
# Out:
# 2/4
# hasil tambah pecahan : 11/15
# hasil kurang pecahan : 1/15
# hasil bagi pecahan : 6/5
# hasil kali pecahan : 2/15

# %% [markdown]
# # ENCAPSULATION

# %% [markdown]
# . Encapsulation?
# . Information Hidding?
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# ![7.JPG](attachment:7.JPG)

# %% [markdown]
# Dalam Program phyton berorientasi objek, anda dapat membatasi akses ke metode dan variabel. ini dapat mencegah data dari dimodifikasi secara tidak sengaja dan dikenal sebagai Encapsulation. Berikut beberapa contoh programnya:

# %%
#encapsulation
class robot(object):
    def __init__(self):
        self.__version=22
    def getversion(self):
        print(self.__version)
    def setversion(self,version):
        self.__version=version
obj=robot()
obj.getversion()
obj.setversion(24)
obj.getversion()
#print(obj.__version)salah karena tidak ada pemanggilan class
print(obj._robot__version)
# Out:
# 22
# 24
# 24

# %%
class car:
    __maxspeed = 0
    __name = ""
    
    def __init__(self):
        self.__maxspeed = 300
        self.__name = "Supercar"
        
    def drive(self):
        print("driving. maxspeed : " + str(self.__maxspeed))
        
redcar = car()
redcar.drive()
redcar.maxspeed = 20 #will not change variable because its private
redcar._car__maxspeed = 20 #cara mengubah variabel private
redcar.drive()
# Out:
# driving. maxspeed : 300
# driving. maxspeed : 20

# %%
class car:
    def __init__(self):
        self.__updatesoftware()
    def drive(self):
        print("driving")
    def __updatesoftware(self):
        print("updating software")
        
redcar = car()
redcar.drive
#redcar.__updatesoftware() not accesible from object.
# Out:
# updating software
# <bound method car.drive of <__main__.car object at 0x000001D94BBDFD68>>
